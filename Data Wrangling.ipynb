# %%
import pandas as pd

# %%
df = pd.read_csv(r'E:\DA project\Software professionals survey\m1_survey_data.csv')

# %%
df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
# Finding duplicate
df.duplicated().sum()
# Out:
# 154

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Respondent'].nunique()
# Out:
# 11398

# %%
# Finding missing value
df.isnull().sum()
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %%
df['WorkLoc'].isnull().sum()
# Out:
# 32

# %%
df['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %%
# Imputing missing values
df['WorkLoc'].fillna( value = 'Office', inplace = True)

# %%
df['WorkLoc'].value_counts()
# Out:
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# # Normalizing data

# %%
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
df['CompFreq'].unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %%
df['CompFreq'].replace()
# Out:
# 0         Yearly
# 1         Yearly
# 2         Yearly
# 3        Monthly
# 4         Yearly
#           ...
# 11547     Yearly
# 11548     Yearly
# 11549     Yearly
# 11550     Yearly
# 11551     Yearly
# Name: CompFreq, Length: 11398, dtype: object

# %%
df["CompFreq"].replace(to_replace="Yearly",value=1,inplace=True)
df["CompFreq"].replace(to_replace="Monthly",value=12,inplace=True)
df["CompFreq"].replace(to_replace="Weekly",value=52,inplace=True)

# %%
df["CompFreq"].unique()
# Out:
# array([ 1., 12., 52., nan])

# %%
df["CompFreq"].value_counts()
# Out:
# 1.0     6073
# 12.0    4788
# 52.0     331
# Name: CompFreq, dtype: int64

# %%
df['NormalizedAnnualCompensation'] = df["CompTotal"] * df["CompFreq"]
df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
df['NormalizedAnnualCompensation'].median()
# Out:
# 100000.0

# %%
df.to_csv("E:\DA project\Software professionals survey\m2_survey_data.csv", index = False)
